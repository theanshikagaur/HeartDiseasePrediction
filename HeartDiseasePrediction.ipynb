# %% [markdown]
# ##This is Heart Disease prediction model trained by Anshika Gaur, The model we have used is Random Forest Classifier and the dataset is from kaggle, here is the link
# https://www.kaggle.com/datasets/emmydesign/cardiovascular-disease-prediction-dataset

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/HeartDiseasePrediction/cardiovascular_disease.csv')
df
# Out:
#     PatientID  Age  Gender   BMI Smoking   Alcohol FamilyHistory  SystolicBP  \
# 0       P0001   59    Male  28.8      No        No            No         110
# 1       P0002   50    Male  22.8      No  Moderate           Yes         139
# 2       P0003   61  Female  28.3      No        No            No         144
# 3       P0004   73  Female  34.1      No  Moderate            No         142
# 4       P0005   49    Male  29.8     Yes        No            No         145
# ..        ...  ...     ...   ...     ...       ...           ...         ...
# 995     P0996   48    Male  28.3      No  Moderate           Yes         138
# 996     P0997   77    Male  19.8      No  Moderate            No         140
# 997     P0998   61    Male  22.7      No        No            No         145
# 998     P0999   44    Male  40.0      No      High            No         130
# 999     P1000   60    Male  25.9      No        No            No         144
#
# ...

# %%
df = df.drop(columns='PatientID')
df
# Out:
#      Age  Gender   BMI Smoking   Alcohol FamilyHistory  SystolicBP  \
# 0     59    Male  28.8      No        No            No         110
# 1     50    Male  22.8      No  Moderate           Yes         139
# 2     61  Female  28.3      No        No            No         144
# 3     73  Female  34.1      No  Moderate            No         142
# 4     49    Male  29.8     Yes        No            No         145
# ..   ...     ...   ...     ...       ...           ...         ...
# 995   48    Male  28.3      No  Moderate           Yes         138
# 996   77    Male  19.8      No  Moderate            No         140
# 997   61    Male  22.7      No        No            No         145
# 998   44    Male  40.0      No      High            No         130
# 999   60    Male  25.9      No        No            No         144
#
#      DiastolicBP  HeartRate  Cholesterol  Glucose  OxygenSaturation  HRV  \
# 0             78         76          225       93              97.1   56
# ...

# %%
df['Gender'] = df['Gender'].map({'Male':1,'Female':0})
df['Alcohol'] = df['Alcohol'].map({'Moderate':1,'No':0,'High':2})
df['Smoking'] = df['Smoking'].map({'Yes':1,'No':0})
df['FamilyHistory'] = df['FamilyHistory'].map({'Yes':1,'No':0})

# %%
df
# Out:
#      Age  Gender   BMI  Smoking  Alcohol  FamilyHistory  SystolicBP  \
# 0     59       1  28.8        0        0              0         110
# 1     50       1  22.8        0        1              1         139
# 2     61       0  28.3        0        0              0         144
# 3     73       0  34.1        0        1              0         142
# 4     49       1  29.8        1        0              0         145
# ..   ...     ...   ...      ...      ...            ...         ...
# 995   48       1  28.3        0        1              1         138
# 996   77       1  19.8        0        1              0         140
# 997   61       1  22.7        0        0              0         145
# 998   44       1  40.0        0        2              0         130
# 999   60       1  25.9        0        0              0         144
#
#      DiastolicBP  HeartRate  Cholesterol  Glucose  OxygenSaturation  HRV  \
# 0             78         76          225       93              97.1   56
# ...

# %%
gendercount = df['Gender'].value_counts()
print(gendercount)
# Out:
# Gender
# 1    509
# 0    491
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# BMI                 0
# Smoking             0
# Alcohol             0
# FamilyHistory       0
# SystolicBP          0
# DiastolicBP         0
# HeartRate           0
# Cholesterol         0
# Glucose             0
# OxygenSaturation    0
# HRV                 0
# RRInterval          0
# QTInterval          0
# QRSDuration         0
# PulseTransitTime    0
# PPGAmplitude        0
# DiseaseLabel        0
# dtype: int64

# %%
df.describe()
# Out:
#                Age       Gender          BMI      Smoking      Alcohol  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     52.294000     0.509000    26.856200     0.213000     0.749000
# std      13.553939     0.500169     4.608027     0.409633     0.653013
# min      20.000000     0.000000    17.500000     0.000000     0.000000
# 25%      43.000000     0.000000    23.675000     0.000000     0.000000
# 50%      52.000000     1.000000    27.000000     0.000000     1.000000
# 75%      61.000000     1.000000    30.100000     0.000000     1.000000
# max      89.000000     1.000000    41.800000     1.000000     2.000000
#
#        FamilyHistory   SystolicBP  DiastolicBP    HeartRate  Cholesterol  \
# count    1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean        0.253000   139.298000    81.054000    75.116000   226.124000
# std         0.434948    15.778852     9.312992     8.477996    29.406519
# ...

# %%
from sklearn.model_selection import train_test_split

x = df.drop(columns='DiseaseLabel')
y = df["DiseaseLabel"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.77

# %%
from sklearn.tree import DecisionTreeClassifier

model2 = DecisionTreeClassifier()
model2.fit(x_train, y_train)
y_pred2 = model2.predict(x_test)
accuracy2 = accuracy_score(y_test, y_pred2)
print("Accuracy:", accuracy2)
# Out:
# Accuracy: 0.755

# %%
from sklearn.svm import SVC
model3 = SVC()
model3.fit(x_train, y_train)
y_pred3 = model3.predict(x_test)
accuracy3 = accuracy_score(y_test, y_pred3)
print("Accuracy:", accuracy3)
# Out:
# Accuracy: 0.675

# %%
from sklearn.neighbors import KNeighborsClassifier
model4 = KNeighborsClassifier()
model4.fit(x_train, y_train)
y_pred4 = model4.predict(x_test)
accuracy4 = accuracy_score(y_test, y_pred4)
print("Accuracy:", accuracy4)
# Out:
# Accuracy: 0.745

# %%
from sklearn.linear_model import LogisticRegression
model5 = LogisticRegression()
model5.fit(x_train, y_train)
y_pred5 = model5.predict(x_test)
accuracy5 = accuracy_score(y_test, y_pred5)
print("Accuracy:", accuracy5)
# Out:
# Accuracy: 0.745
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
columns = x_train.columns
print(columns)
firstrow = [73,0,34.1,0,1,0,142,88,76,230,144,98.5,49,790,415,92,227,1.22,]
mydataset = pd.DataFrame([firstrow],columns=columns)
prediction = model.predict(mydataset)
print("output",prediction)
# Out:
# Index(['Age', 'Gender', 'BMI', 'Smoking', 'Alcohol', 'FamilyHistory',
#        'SystolicBP', 'DiastolicBP', 'HeartRate', 'Cholesterol', 'Glucose',
#        'OxygenSaturation', 'HRV', 'RRInterval', 'QTInterval', 'QRSDuration',
#        'PulseTransitTime', 'PPGAmplitude'],
#       dtype='object')
# output [1]
